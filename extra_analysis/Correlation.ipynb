# %%
import torch
from scipy.stats import pearsonr

# %%
dtws = torch.load("./dtws_mfcc.pt").reshape(-1)
dists = torch.load("./dists.pt").reshape(-1)

# %%
pearsonr(dtws,dists)
# Out:
# PearsonRResult(statistic=0.028452537317260697, pvalue=0.6712034709717093)
